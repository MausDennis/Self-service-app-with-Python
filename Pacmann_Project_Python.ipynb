# %% [markdown]
# # **Hasil Pengerjaan Script**

# %%
# melakukan penyambungan dengan google drive
# melakukan mount di /content/gdrive/
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# upload modul yang dibutuhkan dengan cara mengupload langsung lewat local
from google.colab import files
src = list(files.upload().values())[0]
open('script.py','wb').write(src)
from script import Transaction
# Out:
#      <input type="file" id="files-a303b614-9644-4be3-af13-583865f136e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a303b614-9644-4be3-af13-583865f136e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Custumer membuat ID Transaksi customer
trnsct_123 = Transaction()

# %%
# Test 1: Add Item
# Customer memasukkan nama item, jumlah item dan harga barang
trnsct_123.add_item('Ayam Goreng', 2, 20_000)
trnsct_123.add_item('Pasta Gigi', 3, 15_000)
# Out:
# "Item yang dibeli adalah: {'Ayam Goreng': [2, 20000], 'Pasta Gigi': [3, 15000]}"

# %%
# Test 2: Delete Item
# Customer dapat menghapus item yang telah dimasukkan sebelumnya
trnsct_123.delete_item('Pasta Gigi')
# Out:
# "Item yang dibeli adalah: {'Ayam Goreng': [2, 20000]}"

# %%
# Test 3: Reset Transaction
# Customer juga dapat mereset ulang pesanannya
trnsct_123.reset_transaction()
# Out:
# 'Semua item berhasil didelete!'

# %%
# Customer melakukan check order kembali 
trnsct_123.add_item('Ayam Goreng', 2, 20_000)
trnsct_123.add_item('Pasta Gigi', 3, 15_000)
trnsct_123.add_item('Mainan Mobil', 1, 200_000)
trnsct_123.add_item('Mi Instan', 5, 3_000)
# Out:
# "Item yang dibeli adalah: {'Ayam Goreng': [2, 20000], 'Pasta Gigi': [3, 15000], 'Mainan Mobil': [1, 200000], 'Mi Instan': [5, 3000]}"

# %%
# Test 4: Total Price
# Pada tahap ini, customer melakukan pembayaran terhadap barang - barang yang 
# sudah dibeli sebelumnya
trnsct_123.total_price()
# Out:
# "Item yang dibeli adalah: {'Ayam Goreng': [2, 20000], 'Pasta Gigi': [3, 15000], 'Mainan Mobil': [1, 200000], 'Mi Instan': [5, 3000]}. Selamat! Anda mendapat diskon 5%, total belanja anda: 285000.0"
